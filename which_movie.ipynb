# %%
from pyspark.sql import SparkSession

import pandas as pd

# %%
spark = SparkSession.builder \
    .appName("EntityResolution") \
    .getOrCreate()
# Out:
# 24/10/22 02:37:39 WARN Utils: Your hostname, selena resolves to a loopback address: 127.0.1.1; using 10.86.1.141 instead (on interface wlp0s20f3)
# 24/10/22 02:37:39 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/10/22 02:37:40 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 24/10/22 02:37:41 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
df = pd.read_csv("data/english_movies.csv")
spark_df = spark.createDataFrame(df)
spark_df.show()
# Out:
# 24/10/22 02:39:12 WARN TaskSetManager: Stage 0 contains a task of very large size (4923 KiB). The maximum recommended task size is 1000 KiB.
# +---------+--------------------+--------------------+--------------------+-----+---------------+
# |  imdb_id|               title|       plot_synopsis|                tags|split|synopsis_source|
# +---------+--------------------+--------------------+--------------------+-----+---------------+
# |tt1733125|Dungeons & Dragon...|Two thousand year...|            violence|train|           imdb|
# |tt0033045|The Shop Around t...|Matuschek's, a gi...|            romantic| test|           imdb|
# |tt0113862|  Mr. Holland's Opus|Glenn Holland, no...|inspiring, romant...|train|           imdb|
# |tt0408790|          Flightplan|Kyle Pratt (Jodie...|mystery, suspense...|train|           imdb|
# |tt0078908|           The Brood|At the Somafree I...|cult, psychedelic...|train|           imdb|
# |tt0795493|   Cassandra's Dream|Brothers Terry (C...|tragedy, dramatic...|train|      wikipedia|
# |tt0093389|    The Last Emperor|Arrival.\nA train...|              murder|train|           imdb|
# |tt0120899|      My Life So Far|The film tells th...|flashback, autobi...|train|      wikipedia|
# |tt1937113|Call of Duty: Mod...|Hours after the e...|    good versus evil| test|           imdb|
# |tt1232776|           Fish Tank|We open with Mia ...|suspenseful, depr...|train|           imdb|
# |tt0402399|       The New World|Over a shot of tr...|boring, murder, c...|train|           imdb|
# |tt0102007|         The Haunted|This creepy and s...|paranormal, horro...| test|           imdb|
# |tt0398712|Assault on Precin...|On New Years Eve,...|suspenseful, neo ...|  val|           imdb|
# |tt0036868|The Best Years of...|After World War I...|romantic, histori...|train|      wikipedia|
# |tt2005374|   The Frozen Ground|The film opens in...|    dramatic, murder| test|      wikipedia|
# |tt1454029|            The Help|In civil-rights e...|historical, feel-...|  val|           imdb|
# |tt1411238| No Strings Attached|15 years agoWe se...|boring, adult com...| test|           imdb|
# |tt0118689|                Bean|Mr. Bean (Rowan A...|cult, comedy, ent...|train|           imdb|
# |tt0055505|       Taste of Fear|** CONTAINS SPOIL...|              murder|train|           imdb|
# |tt0053559|           13 Ghosts|The movie opens w...|     revenge, murder| test|           imdb|
# +---------+--------------------+--------------------+--------------------+-----+---------------+
# only showing top 20 rows

# %%
distinct_english_titles = spark_df.select("title").distinct()
movie_list = [row.title for row in distinct_english_titles.collect()]
print("\n Number of distinct English movie titles: ", len(movie_list))
movie_list
# Out:
# 24/10/22 02:42:52 WARN TaskSetManager: Stage 4 contains a task of very large size (4923 KiB). The maximum recommended task size is 1000 KiB.
#  Number of distinct English movie titles:  7557
# ['Big Nothing',
#  "Evolution's Achilles' Heels",
#  'How to Deal',
#  'The Honeymoon Killers',
#  "Cassandra's Dream",
#  'The Final Destination',
#  'Thralls',
#  'Funny Show Part Two: The Video - Movie',
#  'Night of the Lepus',
#  'American History X',
#  'Extremely Loud & Incredibly Close',
#  'Point Break',
#  'The Men Who Stare at Goats',
#  'Pandora and the Flying Dutchman',
#  'Bad Day at Black Rock',
#  'The Wild Bunch',
#  'A Murder of Crows',
#  'Gangs of New York',
#  "That's My Boy",
#  "Cat's Eye",
#  'Confessions of a Shopaholic',
#  'Ghost Town',
#  'Red: Werewolf Hunter',
#  'Chasing Fire',
#  'Maps to the Stars',
#  'Executive Action',
#  'The Heart of No Place',
#  'Terms of Endearment',
#  'Just Before Dawn',
#  "There's Always Vanilla",
#  'The Fisher King',
#  'The Wolverine',
#  'War of the Satellites',
#  'Nine to Five',
#  'The Fall',
#  'The Quatermass Xperiment',
#  'Justice League: War',
#  'GirlFight: inVite',
#  'Dungeons & Dragons: The Book of Vile Darkness',
#  'Foul Play',
#  'Survival of the Dead',
#  'Prom Night',
#  'The Thrill of It All',
#  'Peacock',
#  'Pride and Prejudice and Zombies',
#  'Sky High',
#  'The Host',
#  'Bailout: The Age of Greed',
#  'The Negotiator',
#  'The Frighteners',
#  'Sinbad and the Eye of the Tiger',
#  'Clash of the Titans',
#  'Caniche',
#  'Memoirs of a Geisha',
#  'The Drop',
#  'Some Like It Hot',
#  'Now, Voyager',
#  'The Opposite of Sex',
#  'The Wyvern Mystery',
#  'The Wrestler',
#  'My Life So Far',
#  'All About Eve',
#  'Eternal Sunshine of the Spotless Mind',
#  'First Blood',
#  'American Horror Story',
#  'The Company You Keep',
#  "Billy Lynn's Long Halftime Walk",
#  'The Jacket',
#  'The English Patient',
#  'The Whole Nine Yards',
#  "Pirates of the Caribbean: Dead Man's Chest",
#  'Eaten Alive',
#  'Dracula Has Risen from the Grave',
#  "The Haunting Hour: Don't Think About It",
#  'Scream 3',
#  'Van Wilder: Freshman Year',
#  'The Amazing Spider-Man',
#  'Leprechaun: Back 2 tha Hood',
#  'Flight of the Phoenix',
#  'The Bonfire of the Vanities',
#  'Natural Born Killers',
#  'The Night of the Iguana',
#  'A Christmas Carol',
#  'Teeth',
#  "Who's Afraid of Virginia Woolf?",
#  'New Jack City',
#  'The Brave One',
#  'The Hangover',
#  'Invasion of the Bee Girls',
#  'Psycho IV: The Beginning',
#  'The Wolf Man',
#  'FleshEater',
#  'Mrs. Doubtfire',
#  'Inferno',
#  'The Sand',
#  'Open Season 3',
#  'Star Trek: First Contact',
#  'The Lords of Salem',
#  'Dallas Buyers Club',
#  'Dying Room Only',
#  'Orgy of the Dead',
#  '49th Parallel',
#  'The Godfather',
#  'Harry Brown',
#  "We're the Millers",
#  'X-Men: Apocalypse',
#  'The Human Centipede (First Sequence)',
#  'The Interpreter',
#  'The Great Gatsby',
#  'Blanche Fury',
#  'Catch and Release',
#  'This Means War',
#  'Jesus Christ Vampire Hunter',
#  'Armed and Dangerous',
#  'The Wanderers',
#  'I Love You Phillip Morris',
#  'The Caller',
#  'The Ghost and the Darkness',
#  'Breach',
#  'In a Lonely Place',
#  'The Accountant',
#  'Stand Up Guys',
#  'Romancing the Stone',
#  'The Falling',
#  'The Last Man on Earth',
#  'The Giant Gila Monster',
#  'Starcrash',
#  'Duel in the Sun',
#  'The Funeral',
#  "Monster's Ball",
#  'Creed',
#  "Can't Hardly Wait",
#  'A Sound of Thunder',
#  'Narc',
#  'The Grandmother',
#  'Unaccompanied Minors',
#  'The Gorgon',
#  'Life of Brian',
#  'The Cold Light of Day',
#  'To Kill a Mockingbird',
#  'The Italian Job',
#  'Return of the Fly',
#  'Mr. & Mrs. Smith',
#  'The Medallion',
#  "Assassin's Creed IV: Black Flag",
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#  'Four Christmases',
#  'The Over-the-Hill Gang',
#  'An American Werewolf in London',
#  'Star Wars: Episode I - The Phantom Menace',
#  'The Waltons: A Decade of the Waltons',
#  'Star Trek III: The Search for Spock',
#  'The Good Thief',
#  "It's Magic, Charlie Brown",
#  'The Taking of Pelham 123',
#  'The Quiet Man',
#  'The Game Plan',
#  'High School Musical 2',
#  'Shuttle',
#  'The Wrong Trousers',
#  'The Exorcist',
#  'City Lights',
#  'The Purge: Anarchy',
#  'New Nightmare',
#  'The Terminator',
#  'Sink the Bismarck!',
#  'King Arthur',
#  'The Red House',
#  'The Stepfather',
#  'Mechanic: Resurrection',
#  'Memory Lane',
#  'Men of Honor',
#  'The Shop Around the Corner',
#  'Resurrecting the Champ',
#  'The Hard Corps',
#  'The Sting',
#  'The Towering Inferno',
#  'Is Anybody There?',
#  'The Jungle Book',
#  'You Will Meet a Tall Dark Stranger',
#  'Scary Movie 5',
#  'If....',
#  "A Hard Day's Night",
#  'I Saw What You Did',
#  "Don't Tell Mom the Babysitter's Dead",
#  "Rabbit's Kin",
#  'The Net',
#  'Meet the Feebles',
#  "The Children's Hour",
#  'World Without End',
#  'The Walking Dead: 400 Days',
#  'Jack and Jill',
#  'Broken City',
#  'Drugstore Cowboy',
#  'Colossus: The Forbin Project',
#  'End of Watch',
#  'The Haunted',
#  'Marathon Man',
#  'Red Heat',
#  'Call of Duty: Modern Warfare 3',
#  'X-Men: Days of Future Past',
#  'Night at the Museum',
#  'Puss in Boots',
#  'Rashômon',
#  'In & Out',
#  'The Cooler',
#  'The Simpsons: Hit & Run',
#  'Star Trek V: The Final Frontier',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Pulp Fiction',
#  'Surrogates',
#  'The Brood',
#  'Assault on Precinct 13',
#  'Tristan + Isolde',
#  'The Warriors',
#  'Snow Cake',
#  'Be Cool',
#  'Long-Haired Hare',
#  'War, Inc.',
#  'Batman Beyond: Return of the Joker',
#  'Birdemic: Shock and Terror',
#  'The Poseidon Adventure',
#  'Man of the Year',
#  'The Woman in Black',
#  'A Bronx Tale',
#  'Moonshot',
#  'Becoming Jane',
#  'The Day After Tomorrow',
#  'The Last Emperor',
#  'Willow',
#  'The Station Agent',
#  'Everly',
#  'Captain Phillips',
#  'Panic in the Streets',
#  'Empire of the Sun',
#  'The One-Nighter',
#  'War of the Worlds',
#  'The Color Purple',
#  'Trance',
#  'The Batman vs. Dracula',
#  'Paranormal Activity 2',
#  'Phantasm III: Lord of the Dead',
#  'The Girl with the Dragon Tattoo',
#  "Child's Play",
#  'Drive Angry',
#  'Chronicle',
#  'Arthur',
#  'Taste the Blood of Dracula',
#  'Before Night Falls',
#  'Woman in Gold',
#  'The Lady Vanishes',
#  'The Uninvited',
#  'Whiskey Tango Foxtrot',
#  'Seeking Justice',
#  'Predator 2',
#  'The Matador',
#  'The Ten Commandments',
#  'North Country',
#  'Unknown',
#  'What Lies Beneath',
#  "Summer's Blood",
#  'The Prowler',
#  'Fish Tank',
#  'Saints and Soldiers',
#  'UFO: Target Earth',
#  'The Day of the Jackal',
#  'Beverly Hills Cop',
#  'A Deadly Adoption',
#  'Curse of Chucky',
#  'The Transporter',
#  'Love Happy',
#  'Love at First Bite',
#  'Trainspotting',
#  'How to Make an American Quilt',
#  'Paris, Texas',
#  'Nightmare Beach',
#  'Eagle Eye',
#  'Metal Gear Solid 2: Sons of Liberty',
#  'Red Dead Redemption',
#  'American Dreamz',
#  'Elizabethtown',
#  'San Andreas',
#  'Brief Encounter',
#  'Cube',
#  'Five the Hard Way',
#  'Edward Scissorhands',
#  'Saturday the 14th',
#  'The Karate Kid Part II',
#  'The Good Mother',
#  'The Land Before Time V: The Mysterious Island',
#  'Trailer Park Boys: Countdown to Liquor Day',
#  'The Twilight Saga: New Moon',
#  'Max Payne 2: The Fall of Max Payne',
#  'Thor: The Dark World',
#  'The Little Mermaid II: Return to the Sea',
#  'Judgment Night',
#  'Fletch Lives',
#  'Insidious',
#  'Chinatown',
#  'Me and You and Everyone We Know',
#  'Why Did I Get Married?',
#  'Monsters, Inc.',
#  'Cult of the Cobra',
#  'An Innocent Man',
#  'Nighthawks',
#  'The Children',
#  'Across the Universe',
#  'The Stuff',
#  'The Specialist',
#  'The A-Team',
#  'The Loved Ones',
#  'This Island Earth',
#  'The Devil Bat',
#  'The Silence of the Lambs',
#  'The Naked Mile',
#  'Octopussy',
#  'Scooby-Doo! And the Legend of the Vampire',
#  'Hustle & Flow',
#  'Into the Wild',
#  'The Place Beyond the Pines',
#  'Roy Colt & Winchester Jack',
#  'The Prestige',
#  'Shallow Hal',
#  'BioShock',
#  'The Thin Man Goes Home',
#  'Death Ship',
#  '30 Days of Night: Dark Days',
#  'Lifeforce',
#  'The Asphyx',
#  'All Dogs Go to Heaven',
#  'Jaws: The Revenge',
#  'The Last American Virgin',
#  'The Maltese Falcon',
#  'Teenage Mutant Ninja Turtles II: The Secret of the Ooze',
#  "Miller's Crossing",
#  'Angel and the Badman',
#  'Action of the Tiger',
#  'Ginger Snaps 2: Unleashed',
#  'Wild at Heart',
#  'House on Haunted Hill',
#  'Crimson Peak',
#  'The Day the Earth Stood Still',
#  'Enduring Love',
#  'The Beast of War',
#  'The Last of the Mohicans',
#  'Bra Boys',
#  'Death Race 2',
#  'If These Walls Could Talk',
#  'Summer of Sam',
#  'Sherlock',
#  'The Grand Budapest Hotel',
#  'Princess of Thieves',
#  'About a Boy',
#  'The Two Jakes',
#  'The Faculty',
#  'Sorority Row',
#  'Repo! The Genetic Opera',
#  "The King's Speech",
#  'The Great Escape',
#  'The Prince and the Pauper',
#  'Everything Must Go',
#  'The Mark of Cain',
#  'Massacre at Central High',
#  'Spice World',
#  'Next Day Air',
#  'The Wedding Ringer',
#  'Sabotage',
#  'Flightplan',
#  'Vampires: The Turning',
#  'The Hamiltons',
#  "Bon Voyage, Charlie Brown (and Don't Come Back!!)",
#  'Half-Life',
#  'The Apartment',
#  "Mr. Holland's Opus",
#  'The Spirit',
#  "City Slickers II: The Legend of Curly's Gold",
#  'How to Make a Monster',
#  "Singin' in the Rain",
#  'The Neighbors',
#  'Crimson Tide',
#  'The Terminal',
#  'Torch Song',
#  'The Bourne Identity',
#  'Beverly Hills Cop III',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  'The Last Picture Show',
#  "Ed, Edd n Eddy's Big Picture Show",
#  'Henry: Portrait of a Serial Killer',
#  'The Iron Lady',
#  'Thursday',
#  'Two for the Seesaw',
#  'Prince of Darkness',
#  'The Broken Circle Breakdown',
#  'Dead End',
#  'Sex and Death 101',
#  'Into the Woods',
#  'Seconds',
#  'The Master',
#  'Guardians of the Galaxy',
#  'The Ghost Writer',
#  'Charly',
#  'They Live',
#  'Easy Rider',
#  'A Tale of Two Cities',
#  'Deadly Eyes',
#  'The Best Years of Our Lives',
#  'Three Kings',
#  'The China Syndrome',
#  'Taste of Fear',
#  'Witness for the Prosecution',
#  'Pump Up the Volume',
#  'Hollow Man II',
#  'A Canterbury Tale',
#  'Ghostbusters',
#  'The Chalk Garden',
#  'Starship Troopers 2: Hero of the Federation',
#  'The Initiation',
#  'He Was a Quiet Man',
#  'Tammy and the Bachelor',
#  'The Assignment',
#  'Underworld: Evolution',
#  'The Falcon Out West',
#  'How to Steal a Million',
#  'Furious Seven',
#  'Moonshine Mountain',
#  'The Golden Compass',
#  'I Know Who Killed Me',
#  'The Liberation of L.B. Jones',
#  'The Gift',
#  'Final Chapter: Walking Tall',
#  'The New World',
#  'Seven Years in Tibet',
#  '14 Going on 30',
#  'Sweeney Todd: The Demon Barber of Fleet Street',
#  'Ladies and Gentlemen, the Fabulous Stains',
#  'Buck Privates',
#  'The Mangler',
#  'No Strings Attached',
#  'Thief',
#  "Child's Play 2",
#  'A Perfect World',
#  'In the Land of Blood and Honey',
#  'Saving Private Ryan',
#  'The She-Creature',
#  'Mildred Pierce',
#  'Fireflies in the Garden',
#  'Fright Night Part 2',
#  'Passage to Marseille',
#  'I, Robot',
#  'Carnival of Souls',
#  'The Grapes of Wrath',
#  'The Haunted Palace',
#  'Embrace the Darkness 3',
#  'Final Destination 3',
#  'Texas Chainsaw 3D',
#  'Maid in Manhattan',
#  "The 'Burbs",
#  'The Crazies',
#  "Dante's Cove",
#  "Assassin's Creed",
#  'Me, Myself & Irene',
#  'The Jerk',
#  'Storm of the Century',
#  'Ghostbusters II',
#  'The Lamp',
#  'The Frozen Ground',
#  'A Most Violent Year',
#  'Captain America: The Winter Soldier',
#  'The Witches of Eastwick',
#  'The Perfect Host',
#  "America's Dark Secrets Documentary",
#  'Tom Sawyer',
#  'Transformers: Revenge of the Fallen',
#  'Ghost Rider: Spirit of Vengeance',
#  'Flight',
#  'Bean',
#  'The Exorcism of Emily Rose',
#  'The Lord of the Rings: The Two Towers',
#  'The Constant Gardener',
#  'Joy',
#  'Duck Soup',
#  'Something Borrowed',
#  '12 and Holding',
#  'The Accidental Witness',
#  "One Flew Over the Cuckoo's Nest",
#  'The X Files: I Want to Believe',
#  "The Devil's Double",
#  'Monty Python and the Holy Grail',
#  'The Strangers',
#  'Starting Out in the Evening',
#  'Beasts of the Southern Wild',
#  'Another Earth',
#  'Blade: Trinity',
#  'Metroid Prime 3: Corruption',
#  'The Paperboy',
#  'The Player',
#  'Tenacious D in The Pick of Destiny',
#  'A Boy and His Dog',
#  'A Warning to the Curious',
#  'Marked for Death',
#  'Lord Love a Duck',
#  'High Crimes',
#  'Twilight',
#  'Thir13en Ghosts',
#  '10 Things I Hate About You',
#  'The Space Children',
#  'Tormented',
#  'Circus of Fear',
#  'Slaughterhouse-Five',
#  'Dirty Dancing',
#  'A Walk on the Moon',
#  'A Cure for Wellness',
#  'Cherry Falls',
#  'Planet of the Apes',
#  'Get Shorty',
#  'Wrong Turn 4: Bloody Beginnings',
#  'The Spectacular Now',
#  'Bride of Chucky',
#  'Creepshow',
#  'Atlas Shrugged: Part I',
#  'The Signal',
#  'The Mentalist',
#  'Scary Movie 3',
#  'Children of the Corn',
#  'Peter & the Wolf',
#  '13 Ghosts',
#  'Conquest of the Planet of the Apes',
#  'Code Name: The Cleaner',
#  'Justice League: The New Frontier',
#  'Airport',
#  'The Man with the Golden Gun',
#  'The Canterville Ghost',
#  'The Last Time I Saw Paris',
#  '(500) Days of Summer',
#  'The Incredible Hulk',
#  'Jersey Boys',
#  'The Last House on the Left',
#  'Magic in the Moonlight',
#  'Hacksaw Ridge',
#  'The Book of Life',
#  'Chemical Wedding',
#  'Meet the Hollowheads',
#  'Dom Hemingway',
#  'The Finest Hours',
#  'In Cold Blood',
#  'Harry Potter and the Deathly Hallows: Part 1',
#  'Dead of Night',
#  'The Fountainhead',
#  'Conan the Destroyer',
#  'Water for Elephants',
#  'Halloween H20: 20 Years Later',
#  'Street Fighter: The Legend of Chun-Li',
#  'Tracks',
#  'The Princess Diaries',
#  "Fool's Fire",
#  'Night of the Ghouls',
#  'Teenage Mutant Ninja Turtles: Out of the Shadows',
#  'Hannah Montana: The Movie',
#  'Enter the Matrix',
#  'George and the Dragon',
#  'The Mummy: Tomb of the Dragon Emperor',
#  'The Last King of Scotland',
#  'Southside with You',
#  'Combat Shock',
#  'Stage Fright',
#  'House at the End of the Drive',
#  'Indiana Jones and the Kingdom of the Crystal Skull',
#  'Wreck-It Ralph',
#  'Interview with the Vampire: The Vampire Chronicles',
#  'The Last Temptation of Christ',
#  'Strangers on a Train',
#  'Fantastic Voyage',
#  'Prom',
#  'We Bought a Zoo',
#  'The Monuments Men',
#  'Manos: The Hands of Fate',
#  'Zero Dark Thirty',
#  'The Bourne Legacy',
#  'Rolling',
#  'The Informant!',
#  'The Gay Falcon',
#  'Bad Words',
#  'Sometimes They Come Back',
#  'Broken Blossoms or The Yellow Man and the Girl',
#  'The Bourne Supremacy',
#  'Trainwreck',
#  'The Duellists',
#  'The Palm Beach Story',
#  'Little Children',
#  'I Bury the Living',
#  'Performance',
#  'Very Bad Things',
#  'Chernobyl Diaries',
#  'The Purge: Election Year',
#  'It Follows',
#  'Scarlet Street',
#  'The Man Who Would Be King',
#  'Eye of the Needle',
#  'The Runaways',
#  'The F Word',
#  'The Happening',
#  'The Ape Man',
#  'V: The Final Battle',
#  'Ghost Story',
#  "Shoot 'Em Up",
#  'Lady in the Water',
#  'Places in the Heart',
#  'King of the Zombies',
#  'This Is England',
#  'Hard Candy',
#  'Rites of Passage',
#  'Dr. Who and the Daleks',
#  'Fighting',
#  'The Machine',
#  'Scream',
#  'Star Trek VI: The Undiscovered Country',
#  'Autism: The Musical',
#  'Piranha Part Two: The Spawning',
#  'Die Hard with a Vengeance',
#  'Twins',
#  'The Girl Next Door',
#  'The Mummy',
#  'The Tale of Despereaux',
#  'The Joy Luck Club',
#  'Me Before You',
#  'The Boy Who Could Fly',
#  'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan',
#  'The Offence',
#  'The Sword in the Stone',
#  'The Help',
#  'Bowling for Columbine',
#  'Moscow on the Hudson',
#  "Sgt. Pepper's Lonely Hearts Club Band",
#  'The Core',
#  'Enthiran',
#  'Dead & Breakfast',
#  'Ready to Rumble',
#  'An Awfully Big Adventure',
#  'Along Came a Spider',
#  'Ted',
#  'Death Wish',
#  'Touch',
#  'Great Expectations',
#  "Cats Don't Dance",
#  'Night of Dark Shadows',
#  'The Ring',
#  'Womb',
#  '13 Going on 30',
#  'Ms .45',
#  'American Pastoral',
#  'The Rite',
#  'London Has Fallen',
#  'Love Bites',
#  'Grease 2',
#  'Atlantic Rim',
#  'The Naked Gun: From the Files of Police Squad!',
#  'Until Death',
#  'The Addiction',
#  'A Shot in the Dark',
#  'Pitch Perfect',
#  'Day of the Dead',
#  'The Wisdom of Crocodiles',
#  'After the Sunset',
#  'Friday the 13th Part III',
#  'Life Is Hot in Cracktown',
#  "Uncharted 3: Drake's Deception",
#  'Ruthless People',
#  'Heavenly Creatures',
#  'The Kid',
#  'Friends with Kids',
#  'The Return of the Living Dead',
#  'The Texas Chainsaw Massacre',
#  'Safety Not Guaranteed',
#  'Born to Win',
#  'The Game',
#  'Deadly Is the Female',
#  'Boy Eats Girl',
#  'Detective Byomkesh Bakshy!',
#  'Crossing Over',
#  'Seven Psychopaths',
#  'The Lawnmower Man',
#  'Naked Lunch',
#  'The Proposal',
#  'The Double',
#  'City That Never Sleeps',
#  'Something Wild',
#  'The Forsaken',
#  'Alone in the Dark',
#  'Billy Madison',
#  'I Can Do Bad All by Myself',
#  'In the Company of Men',
#  'Mr. Mom',
#  'Prime Suspect: The Scent of Darkness',
#  'The Baytown Outlaws',
#  'Lost River',
#  'The Philadelphia Story',
#  'The Virgin and the Gypsy',
#  'Death Wish 3',
#  'The Vow',
#  'The Seeker: The Dark Is Rising',
#  'Poetic Justice',
#  'The Nice Guys',
#  'Wild Things: Diamonds in the Rough',
#  'Dawn of the Dead',
#  'The Rules of Attraction',
#  'Marooned',
#  'Hold That Ghost',
#  'Memoirs of an Invisible Man',
#  'Five Easy Pieces',
#  'Dream House',
#  'The Brown Bunny',
#  'Down Periscope',
#  'Wrong Turn 3: Left for Dead',
#  'Black Christmas',
#  'The Whales of August',
#  "She's the One",
#  'The Outsiders',
#  'Murder on the Orient Express',
#  'Halloween III: Season of the Witch',
#  'Affair with a Stranger',
#  'The Brides of Dracula',
#  'The Rescuers',
#  'Trick or Treat',
#  'In a World...',
#  'Thale',
#  'Westworld',
#  'Butterfly on a Wheel',
#  "He's Just Not That Into You",
#  'Fear Chamber',
#  'Adoration',
#  'Uptown Girls',
#  'Call of the Flesh',
#  'The Small Back Room',
#  'The Expendables 3',
#  'Adventureland',
#  'Precious',
#  "Charlotte's Web",
#  'Metal Gear Solid 3: Snake Eater',
#  'The Unborn',
#  'The Wizard of Oz',
#  'Sky Captain and the World of Tomorrow',
#  'While She Was Out',
#  'Battlefield Earth',
#  'The Final Cut',
#  'The Bodyguard',
#  "Nick and Norah's Infinite Playlist",
#  'The Haunting',
#  'Taylor Swift: Bad Blood',
#  'Simply Irresistible',
#  'Crash',
#  'Twilight Zone: The Movie',
#  'Underworld: Rise of the Lycans',
#  'The Lazarus Effect',
#  'Color of Night',
#  'It Happened One Night',
#  'The People vs. Larry Flynt',
#  'Red Water',
#  'Undisputed II: Last Man Standing',
#  "The Farmer's Wife",
#  'Speed Racer',
#  'The Wolf of Wall Street',
#  'Spaceballs',
#  'Man of Steel',
#  'Friday the 13th Part 2',
#  'The Matrix Revolutions',
#  'Swiss Army Man',
#  'The Pursuit of Happyness',
#  'Gods and Monsters',
#  'Leviathan',
#  'Ice Station Zebra',
#  'The Nitwits',
#  'A Very Harold & Kumar 3D Christmas',
#  'Vanity Fair',
#  'Rawhead Rex',
#  'The Hills Have Eyes',
#  'Starship Troopers 3: Marauder',
#  'The Wedding Singer',
#  'Everything You Always Wanted to Know About Sex * But Were Afraid to Ask',
#  'Splendor in the Grass',
#  'I Now Pronounce You Chuck & Larry',
#  'Dan in Real Life',
#  'Higher Learning',
#  'Hey, Happy!',
#  'Fright Night',
#  'The Great Race',
#  'This Is the End',
#  "Mom's Got a Date with a Vampire",
#  'Magical Mystery Tour',
#  'Cemetery Junction',
#  'Take Me Home Tonight',
#  'Back to the Beach',
#  'Underworld: Blood Wars',
#  'Black Sunday',
#  'Dasavatharam',
#  'The Hand',
#  "The Devil's Hand",
#  'Charlie and the Chocolate Factory',
#  'Emperor of the North Pole',
#  'This House Possessed',
#  'Wicked Little Things',
#  'The Family Stone',
#  'Mary and Max',
#  'Ghosts of Girlfriends Past',
#  'Far and Away',
#  'Premonition',
#  'Black Death',
#  'The Guns of Navarone',
#  'The Pagemaster',
#  'Return to the Blue Lagoon',
#  'Jack the Giant Slayer',
#  'The Giver',
#  'The Five-Year Engagement',
#  'The Fury',
#  'Teaching Mrs. Tingle',
#  'The Panic in Needle Park',
#  'Away from Her',
#  'Dracula: Dead and Loving It',
#  'Humanoids from the Deep',
#  'Following',
#  'Reflections in a Golden Eye',
#  'The Chronicles of Riddick',
#  'The Godfather: Part III',
#  'A Night at the Opera',
#  'Twin Peaks: Fire Walk with Me',
#  'The Monster of Piedras Blancas',
#  'Home Alone 2: Lost in New York',
#  'The Great Mouse Detective',
#  'The War of the Worlds',
#  'The Incredible Shrinking Woman',
#  'Creepshow 3',
#  'The Perfect Storm',
#  'Messiah of Evil',
#  'Snowbeast',
#  'The Boondock Saints II: All Saints Day',
#  'The Fighting Temptations',
#  'The Deadly Spawn',
#  'Crimes of Passion',
#  'Spirit: Stallion of the Cimarron',
#  'The French Connection',
#  'Lady in White',
#  'Plain Clothes',
#  'Mars Attacks!',
#  'The Hand That Rocks the Cradle',
#  'The Incredible Shrinking Man',
#  'Father of the Bride',
#  'The Treasure of the Sierra Madre',
#  'The Adventures of Pluto Nash',
#  'The Wicker Tree',
#  'Demetrius and the Gladiators',
#  'Time Chasers',
#  'Cool Hand Luke',
#  '2-Headed Shark Attack',
#  'The Torturer',
#  'The Emerald Forest',
#  'The Usual Suspects',
#  'The Night Before',
#  'American Gigolo',
#  'A Nightmare on Elm Street 4: The Dream Master',
#  'The Grasshopper and the Ants',
#  'The Woman',
#  'Freddy vs. Jason',
#  'Bag of Bones',
#  'Body of Lies',
#  'Shadow of a Doubt',
#  'The Prisoner of Zenda',
#  'Shadow of the Vampire',
#  "Wayne's World 2",
#  'The Van',
#  'Super Bowl XIII',
#  'Under the Skin',
#  'Fur: An Imaginary Portrait of Diane Arbus',
#  'The Russians Are Coming the Russians Are Coming',
#  "The Hitchhiker's Guide to the Galaxy",
#  'Out of Sight',
#  'Lord of War',
#  'Johnny Dangerously',
#  'Shrek the Third',
#  'The 5th Wave',
#  'The Lighthorsemen',
#  'Escape to Witch Mountain',
#  'Carnal Knowledge',
#  'Letters to Juliet',
#  "The Devil's Rejects",
#  'Billy Elliot',
#  'Good Night, and Good Luck.',
#  'The Way Back',
#  'Lost Highway',
#  "Mickey's Christmas Carol",
#  'As Above, So Below',
#  'Beauty and the Beast',
#  'Edge of Darkness',
#  'Toy Story 2',
#  'Man of the West',
#  'Where to Invade Next',
#  'John Carter',
#  'Streets of Blood',
#  'The Stepford Wives',
#  'My Dear Secretary',
#  'Abraham Lincoln: Vampire Hunter',
#  'The Nutcracker',
#  'Mystery Science Theater 3000: The Movie',
#  'Super Bowl IX',
#  'Bridge of Spies',
#  'The Sand Pebbles',
#  'A History of Violence',
#  'Happy Gilmore',
#  'In the Name of the Father',
#  'Bounce',
#  'In God We Tru$t',
#  'The Hours',
#  'To Save a Life',
#  'Blood and Lace',
#  "A Nightmare on Elm Street Part 2: Freddy's Revenge",
#  'The Band Wagon',
#  'Metal Gear Solid',
#  'Midnight in Paris',
#  'Pretty Baby',
#  'Whip It',
#  'The League of Extraordinary Gentlemen',
#  'Blades of Glory',
#  "Satan's Little Helper",
#  'Kingsman: The Secret Service',
#  'The Assassination of Jesse James by the Coward Robert Ford',
#  'Apocalypto',
#  'The Girl on the Train',
#  'They Call Me Mister Tibbs!',
#  'Cherry, Harry & Raquel!',
#  'Final Destination',
#  "Dead Man's Shoes",
#  'Notorious',
#  'Behind the Candelabra',
#  'An American Tail: Fievel Goes West',
#  'Drive In Massacre',
#  'Star Trek IV: The Voyage Home',
#  'The Cabin in the Woods',
#  'Bride of the Monster',
#  'Resident Evil: Apocalypse',
#  'Dogfight',
#  'The Insatiable',
#  'Deception',
#  'Scott Pilgrim vs. the World',
#  'An Officer and a Gentleman',
#  'Feast',
#  'Warrior',
#  'The Lego Movie',
#  'Falling Down',
#  'Mega Shark vs. Giant Octopus',
#  'The Golden Voyage of Sinbad',
#  'Aliens in the Attic',
#  'The Magic of Belle Isle',
#  'The Kids Are All Right',
#  'Silent Night, Deadly Night',
#  'Earth Angel',
#  'Scoop',
#  'Run All Night',
#  'The Black Cat',
#  'Dawn of the Planet of the Apes',
#  'Hell or High Water',
#  'Faintheart',
#  'The Doors',
#  "Harry Potter and the Sorcerer's Stone",
#  'Once Upon a Time',
#  'Cold Case',
#  'Persons Unknown',
#  'The Hurt Locker',
#  'Seeking a Friend for the End of the World',
#  'Iron Man Three',
#  'Anatomy of a Murder',
#  'E.T. the Extra-Terrestrial',
#  'The Watcher',
#  'The Wicker Man',
#  'Witchcraft 7: Judgement Hour',
#  'Come See the Paradise',
#  'Friday the 13th',
#  'The Tournament',
#  'The Final',
#  'Phantasm IV: Oblivion',
#  'The 100',
#  'To Catch a Thief',
#  'The Philadelphia Experiment',
#  'Trading Places',
#  'Five Graves to Cairo',
#  'The Sound of Music',
#  'Catwoman',
#  'Wicked Lake',
#  'The Resident',
#  'Mystery Road',
#  'Double Jeopardy',
#  'Fantastic Four',
#  'Werewolf: The Beast Among Us',
#  'Dressed to Kill',
#  'Victory',
#  'The Losers',
#  'The Sandpiper',
#  'Inglourious Basterds',
#  'Sex Tape',
#  'Straight Time',
#  'The Bounty',
#  'Universal Soldier: The Return',
#  'Sleepy Hollow',
#  ...]

# %%
from pyspark.sql.functions import col, regexp_extract
import re

# %%
escaped_titles = [re.escape(title) for title in movie_list]
movie_pattern = "|".join(escaped_titles)

# %%
reddit_df = pd.read_csv("data/reddit_posts.csv")
reddit_df = spark.createDataFrame(reddit_df)
reddit_df.show()
# Out:
# +--------------------+--------------------+-----+-----+---+------------+----------+-----------+----------+
# |               title|             content|score|   id|url|num_comments|   created|  subreddit|      date|
# +--------------------+--------------------+-----+-----+---+------------+----------+-----------+----------+
# |Hellboy II: The G...|                 NaN|    7|am07r|NaN|           0|1262739798|moviecritic|2010-01-01|
# |At Play in the Fi...|                 NaN|    6|ammjm|NaN|           2|1262859933|moviecritic|2010-01-01|
# |Blacktrospective ...|                 NaN|    1|aklk1|NaN|           0|1262379003|moviecritic|2010-01-01|
# |Movie Tuesday « 1...|                 NaN|    1|ako0b|NaN|           0|1262401769|moviecritic|2010-01-01|
# |Let the WTFs Fly:...|                 NaN|    1|ale17|NaN|           0|1262615469|moviecritic|2010-01-01|
# |20 Best Vampire M...|                 NaN|    1|almm3|NaN|           0|1262663783|moviecritic|2010-01-01|
# |One More for Good...|                 NaN|    1|amqdk|NaN|           0|1262879442|moviecritic|2010-01-01|
# |Review: It's Comp...|                 NaN|    1|amwjk|NaN|           0|1262906812|moviecritic|2010-01-01|
# |Movies from Bolly...|                 NaN|    1|akukx|NaN|           0|1262457776|moviecritic|2010-01-01|
# |The Road Review ;...|                 NaN|    1|alteb|NaN|           0|1262704593|moviecritic|2010-01-01|
# |Dr. Doom Reviews ...|                 NaN|    1|amb7b|NaN|           1|1262795529|moviecritic|2010-01-01|
# |Yes Twilight suck...|LTROI showed up o...|  244|amjpt|NaN|         122|1262839417|     movies|2010-01-01|
# |Avatar Passed $1 ...|                 NaN|  196|al3vl|NaN|         122|1262541956|     movies|2010-01-01|
# |The wild success ...|                 NaN|  176|alwai|NaN|         120|1262717643|     movies|2010-01-01|
# |Yes, that is Mich...|                 NaN|  161|amuoy|NaN|          71|1262897028|     movies|2010-01-01|
# |Warner Bros. new ...|                 NaN|  111|amf21|NaN|          91|1262812450|     movies|2010-01-01|
# |"Slimer" Screen T...|                 NaN|  107|akk9a|NaN|          20|1262368148|     movies|2010-01-01|
# |Koyaanisqatsi (fu...|                 NaN|   90|aktkd|NaN|          29|1262450423|     movies|2010-01-01|
# |At long last, an ...|                 NaN|   82|amjod|NaN|          19|1262839066|     movies|2010-01-01|
# |'Stolz Der Nation...|                 NaN|   67|alqti|NaN|          30|1262690139|     movies|2010-01-01|
# +--------------------+--------------------+-----+-----+---+------------+----------+-----------+----------+
# only showing top 20 rows

# %%
entities_matched = reddit_df.withColumn("movie_title", regexp_extract(col("title"), movie_pattern, 0))
entities_matched.show(truncate=False)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+-----+---+------------+----------+-----------+----------+---------------------------------+
# |title                                                                                                                                        |content                                                                                                                                                                                                                                                                                                                                                                                                |score|id   |url|num_comments|created   |subreddit  |date      |movie_title                      |
# +---------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+-----+---+------------+----------+-----------+----------+---------------------------------+
# |Hellboy II: The Golden Army (2008)                                                                                                           |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |7    |am07r|NaN|0           |1262739798|moviecritic|2010-01-01|Hellboy II: The Golden Army      |
# |At Play in the Fields of the Lord (1991)                                                                                                     |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |6    |ammjm|NaN|2           |1262859933|moviecritic|2010-01-01|At Play in the Fields of the Lord|
# |Blacktrospective 2009                                                                                                                        |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |1    |aklk1|NaN|0           |1262379003|moviecritic|2010-01-01|Black                            |
# |Movie Tuesday « 1 Thought 2 Many                                                                                                             |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |1    |ako0b|NaN|0           |1262401769|moviecritic|2010-01-01|                                 |
# |Let the WTFs Fly: The Ten Best Movies of the Decade                                                                                          |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |1    |ale17|NaN|0           |1262615469|moviecritic|2010-01-01|                                 |
# |20 Best Vampire Movies of All Time                                                                                                           |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |1    |almm3|NaN|0           |1262663783|moviecritic|2010-01-01|                                 |
# |One More for Good Measure: Another Top Ten of the Decade                                                                                     |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |1    |amqdk|NaN|0           |1262879442|moviecritic|2010-01-01|                                 |
# |Review: It's Complicated                                                                                                                     |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |1    |amwjk|NaN|0           |1262906812|moviecritic|2010-01-01|It                               |
# |Movies from Bollywood in 2009 - A Review                                                                                                     |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |1    |akukx|NaN|0           |1262457776|moviecritic|2010-01-01|                                 |
# |The Road Review ;  TheChez.net                                                                                                               |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |1    |alteb|NaN|0           |1262704593|moviecritic|2010-01-01|The Road                         |
# |Dr. Doom Reviews The Lovely Bones                                                                                                            |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |1    |amb7b|NaN|1           |1262795529|moviecritic|2010-01-01|The Lovely Bones                 |
# |Yes Twilight sucks, and so does all the vampire craze.  But if you haven't seen "Let The Right One In", see it this week.  Great movie!      |LTROI showed up on some list I read, a link I followed a Reddit submission, some list about top movies of last decade.  The writer mentioned how good the movie was.  He was right.  It's from 2008, but I just found out about it.\n\nThe pool scene alone at the end of the movie is etched into my brain as a classic scene.\n\nForget all the vampire crap out there right now.  Go see this movie.|244  |amjpt|NaN|122         |1262839417|movies     |2010-01-01|Twilight                         |
# |Avatar Passed $1 Billion Worldwide in Just 17 Days of Release - A Amazing Feat, since The Dark Knight took 197 Days to Reach the same Amount |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |196  |al3vl|NaN|122         |1262541956|movies     |2010-01-01|Release                          |
# |The wild success of Avatar is making conservatives crazy.                                                                                    |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |176  |alwai|NaN|120         |1262717643|movies     |2010-01-01|                                 |
# |Yes, that is Michael Cera. With a flaming sword. I am excited for Scott Pilgrim vs. The World.                                               |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |161  |amuoy|NaN|71          |1262897028|movies     |2010-01-01|                                 |
# |Warner Bros. new releases to stay off Netflix for 28 days                                                                                    |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |111  |amf21|NaN|91          |1262812450|movies     |2010-01-01|                                 |
# |"Slimer" Screen Test Footage from 'Ghostbusters II'                                                                                          |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |107  |akk9a|NaN|20          |1262368148|movies     |2010-01-01|Ghostbusters                     |
# |Koyaanisqatsi (full movie)                                                                                                                   |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |90   |aktkd|NaN|29          |1262450423|movies     |2010-01-01|                                 |
# |At long last, an answer to the long-awaited question, "What if William Shakespeare wrote The Big Lebowski"?                                  |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |82   |amjod|NaN|19          |1262839066|movies     |2010-01-01|The Big Lebowski                 |
# |'Stolz Der Nation', the film-within-a-film from Inglourious Basterds, in full                                                                |NaN                                                                                                                                                                                                                                                                                                                                                                                                    |67   |alqti|NaN|30          |1262690139|movies     |2010-01-01|Inglourious Basterds             |
# +---------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----+-----+---+------------+----------+-----------+----------+---------------------------------+
# only showing top 20 rows

# %%
print("\n Number of entities matched: ", entities_matched.filter(col("movie_title") != "").count())
# Out:
# 24/10/22 03:19:58 WARN TaskSetManager: Stage 11 contains a task of very large size (1316 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 11:==============================================>         (10 + 2) / 12]
#  Number of entities matched:  13896

# %%
pandas_entities_matched = entities_matched.toPandas()
pandas_entities_matched.to_csv("data/entities_matched.csv", index=False)
# Out:
# 24/10/22 03:13:25 WARN TaskSetManager: Stage 10 contains a task of very large size (1316 KiB). The maximum recommended task size is 1000 KiB.

# %% [markdown]
# ## Spacy NER

# %%
import spacy
from spacy.pipeline import EntityRuler

nlp = spacy.load("en_core_web_sm")

# %%
ruler = ruler = nlp.add_pipe("entity_ruler", before="ner")

patterns = [{"label": "MOVIE", "pattern": title} for title in movie_list]
ruler.add_patterns(patterns)

# %%
nlp.add_pipe(ruler, before="ner")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 nlp.add_pipe(ruler, before="ner")
#
# File ~/.local/lib/python3.10/site-packages/spacy/language.py:810, in Language.add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     808     bad_val = repr(factory_name)
#     809     err = Errors.E966.format(component=bad_val, name=name)
# --> 810     raise ValueError(err)
#     811 name = name if name is not None else factory_name
#     812 if name in self.component_names:
#
# ValueError: [E966] `nlp.add_pipe` now takes the string name of the registered component factory, not a callable component. Expected string, but got <spacy.pipeline.entityruler.EntityRuler object at 0x7427eeffeac0> (name: 'None').
#
# - If you created your component with `nlp.create_pipe('name')`: remove nlp.create_pipe and call `nlp.add_pipe('name')` instead.
#
# - If you passed in a component like `TextCategorizer()`: call `nlp.add_pipe` with the string name instead, e.g. `nlp.add_pipe('textcat')`.
#
# - If you're using a custom component: Add the decorator `@Language.component` (for function components) or `@Language.factory` (for class components / factories) to your custom component and assign it a name, e.g. `@Language.component('your_name')`. You can then run `nlp.add_pipe('your_name')` to add it to the pipeline.
